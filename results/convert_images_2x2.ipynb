# %%
# code for displaying multiple images in one figure

#import libraries
import os
import cv2
from matplotlib import pyplot as plt


## FOR 2x2 COMBINED IMAGE GENERATION LOSSESS GRAPHS

# create figure
fig = plt.figure(figsize=(7, 5))


# setting values to rows and column variables
rows = 2
columns = 2

# reading images
Image1 = cv2.imread('4GPU/descriminator_fake_losses.png')
Image2 = cv2.imread('4GPU/descriminator_real_losses.png')
Image3 = cv2.imread('4GPU/generator_adv_losses.png')
Image4 = cv2.imread('4GPU/generator_recon_losses.png')

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("descriminator_fake_losses")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)

# showing image
plt.imshow(Image2)
plt.axis('off')
plt.title("descriminator_real_losses")

# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)

# showing image
plt.imshow(Image3)
plt.axis('off')
plt.title("generator_adv_losses.png")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)

# showing image
plt.imshow(Image4)
plt.axis('off')
plt.title("generator_recon_losses.png")

fig.savefig('4GPU/combined.png')

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 60.5 MB 33.1 MB/s eta 0:00:01.8 MB 33.1 MB/s eta 0:00:02     |███████████████████████████▌    | 52.1 MB 33.1 MB/s eta 0:00:01
# ...
